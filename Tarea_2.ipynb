# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Jesús Sebastián González Ortiz y Tania Bell Nicholls
#
# **Fecha:** 04 de septiembre del 2021.
#
# **Expediente** : IF721621, IF726767.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Tania-Bell/Tarea2_TBell_JSGonzalez.git
#
# # Tarea 2: Clase 4

# %% [markdown]
# ### Enunciado 1:

# %% [markdown]
# 1. Imagine una rutina contable utilizada en una librería. Funciona en una lista con sublistas, que se ven así:
# ![image-2.png](attachment:image-2.png)
# Escriba un programa en Python, que devuelve una lista con tuplas de tamaño 2. Cada tupla consiste en el número de pedido y el costo total del pedido. El producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.
# Escribe un programa Python usando unicamente las funciones **lambda y map**.
#
# `orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95],
#            ["98762", "Programming Python, Mark Lutz", 5, 56.80],
#            ["77226", "Head First Python, Paul Barry", 3,32.95],
#            ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]`

# %%
import numpy as np

# %%
########### Solución 1 estudiante 1
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

number = list(map(lambda o: int(orders[o][0]), range(len(orders))))
quantity = list(map(lambda o: float(orders[o][2]), range(len(orders))))
price_u = list(map(lambda o: float(orders[o][3]), range(len(orders))))
price_t = np.array(quantity)*np.array(price_u)
price_t2 = list(map(lambda j: j if j > 100 else j + 10 , price_t))
lista = list(map(lambda m, n: (m, n), number, price_t2))
lista
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]

# %%
########### Solución 1 estudiante 2
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

number = list(map(lambda o: int(orders[o][0]), range(len(orders))))
quantity = list(map(lambda o: float(orders[o][2]), range(len(orders))))
price_u = list(map(lambda o: float(orders[o][3]), range(len(orders))))
price_t = np.array(quantity)*np.array(price_u)
price_t2 = list(map(lambda j: j if j > 100 else j + 10 , price_t))
lista = list(map(lambda m, n: (m, n), number, price_t2))
lista
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]

# %% [markdown]
# ### Enunciado 2
#
# 2. La misma librería, pero esta vez trabajamos en una lista diferente. Las sublistas de nuestras listas se ven así:
# [número de orden, (número de artículo, cantidad, precio por unidad), ... (número de artículo, cantidad, precio por unidad)]
#
# `orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)],
# 	       [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
# 	       [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
#            [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]`
#
# Escriba un programa que devuelva una lista de dos tuplas que tengan la información de (número de pedido, cantidad total de pedido). Utilice la función `Reduce`. Recuerde el precio del pedido del producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.

# %%
########### Solución 2 estudiante 1
from functools import reduce
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

red = lambda r : (reduce((lambda x, y: x*y) , r))
number = list(map(lambda o: o[0], orders))
quantity = list(map(lambda n: 
                    n[1][1]*n[1][2]+n[2][1]*n[2][2]+n[3][1]*n[3][2] if len(n) == 4 else n[1][1]*n[1][2]+n[2][1]*n[2][2], orders))
quantity
# Out:
# [678.3299999999999, 494.46000000000004, 364.79999999999995, 492.57]

# %%
########### Solución 2 estudiante 2
from functools import reduce
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

red = lambda r : (reduce((lambda x, y: x*y) , r))
number = list(map(lambda o: o[0], orders))
quantity = list(map(lambda n: 
                    n[1][1]*n[1][2]+n[2][1]*n[2][2]+n[3][1]*n[3][2] if len(n) == 4 else n[1][1]*n[1][2]+n[2][1]*n[2][2], orders))
quantity
# Out:
# [678.3299999999999, 494.46000000000004, 364.79999999999995, 492.57]

# %% [markdown]
# ### Enunciado 3
#
# 3. Resolver los anteriores ejercicios usando pandas (DataFrame)

# %%
import pandas as pd

# %%
########### Solución 1 pandas estudiante 1
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]
orders_pd = pd.DataFrame(orders).drop([1], axis=1)
orders_pd['sol1'] = orders_pd[2] * orders_pd[3]
orders_pd['sol1'] = orders_pd['sol1'].apply(lambda x: x+10 if x < 100 else x)
orders_pd.drop([2,3],axis=1)
# Out:
#        0    sol1
# 0  34587  163.80
# 1  98762  284.00
# 2  77226  108.85
# 3  88112   84.97

# %%
########### Solución 1 pandas estudiante 2
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]
orders_pd = pd.DataFrame(orders).drop([1], axis=1)
orders_pd['sol1'] = orders_pd[2] * orders_pd[3]
orders_pd['sol1'] = orders_pd['sol1'].apply(lambda x: x+10 if x < 100 else x)
orders_pd.drop([2,3],axis=1)
# Out:
#        0    sol1
# 0  34587  163.80
# 1  98762  284.00
# 2  77226  108.85
# 3  88112   84.97

# %%
########### Solución 2 pandas estudiante 1
from functools import reduce
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

# %%
########### Solución 2 pandas estudiante 2
from functools import reduce
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

# %% [markdown]
# ### Enunciado 4
#
# 4. Use filter to eliminate all words that are shorter than 4 letters from a list of words
# `list='the notion of a lambda function goes all the way back to the origin of computer science'`

# %%
########### Solución 4 estudiante 1
list1 = 'the notion of a lambda function goes all the way back to the origin of computer science'
list2 = list(filter(lambda x : len(x) >= 4, list1.split()))
list2
# Out:
# ['notion',
#  'lambda',
#  'function',
#  'goes',
#  'back',
#  'origin',
#  'computer',
#  'science']

# %%
########### Solución 4 estudiante 2
list1 = 'the notion of a lambda function goes all the way back to the origin of computer science'
list2 = list(filter(lambda x : len(x) >= 4, list1.split()))
list2
# Out:
# ['notion',
#  'lambda',
#  'function',
#  'goes',
#  'back',
#  'origin',
#  'computer',
#  'science']

# %% [markdown]
# ### Enunciado 5
#
# 5. Use filter to determine the percentage of Fahrenheit temperatures in a list are within the range 32 to 80

# %%
########### Solución 5
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)
print(temperatures)
# Out:
# [ 35.97387961  99.13294268  92.6178302   99.69549478  63.21119535
#   73.90387697  95.50028838  99.21476553  36.98251238 101.45813729
#  100.5917418   89.38159435  89.52156589  83.8084752   28.37990868
#   68.75395211  45.86132067  36.58307493  56.32208365  33.96219302
#   45.29071318  74.86289938  66.51091383  88.19316186  94.26635864
#   46.83131624 109.60744472 109.68427993  44.55796499  92.84146259]

# %%
########### Solución 5 estudiante 1
temperature2 = list(filter(lambda x : 32 <= x <= 80, temperatures))
tempperc = len(temperature2) / len(temperatures)
tempperc
# Out:
# 0.4666666666666667

# %%
########### Solución 5 estudiante 2
temperature2 = list(filter(lambda x : 32 <= x <= 80, temperatures))
tempperc = len(temperature2) / len(temperatures)
tempperc
# Out:
# 0.4666666666666667

# %% [markdown]
# ### Enunciado 6
#
# 6. Use reduce to find the lower left corner (minimum x and minimum y value) for a list of point locations
# > **Hint**: Explore the command `np.minimum.reduce` [link](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ufunc.reduce.html)

# %%
########### Solución 6
np.random.seed(55555)
point_xy = np.random.randint(0,100,[30,2])
print(point_xy)
# Out:
# [[17 97]
#  [22 33]
#  [37 46]
#  [57 28]
#  [11 25]
#  [14  2]
#  [74 16]
#  [12 37]
#  [35 21]
#  [66 65]
#  [86 58]
#  [67 81]
#  [ 0 48]
#  [28 66]
#  [76 22]
#  [46 47]
#  [64  7]
#  [88 94]
#  [65 13]
#  [75 89]
#  [23 17]
#  [36 63]
#  [62 36]
#  [64 17]
#  [18 19]
#  [88 41]
#  [21 49]
#  [98 36]
#  [81 73]
#  [62 90]]

# %%
########### Solución 6 estudiante 1
min_red = [np.minimum.reduce(list(map(lambda i: point_xy[i][0], range(len(point_xy))))), 
           np.minimum.reduce(list(map(lambda i: point_xy[i][1], range(len(point_xy)))))]
min_red
# Out:
# [0, 2]

# %%
########### Solución 6 estudiante 2
min_red = [np.minimum.reduce(list(map(lambda i: point_xy[i][0], range(len(point_xy))))), 
           np.minimum.reduce(list(map(lambda i: point_xy[i][1], range(len(point_xy)))))]
min_red
# Out:
# [0, 2]
